# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import math
from sklearn.model_selection import train_test_split
from dataclasses import dataclass
import matplotlib as plt
from scipy.stats import norm
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=10000, n_features=2, centers = 2)
# Out:
# (10000, 2)

# %%
print(X)

print(X.shape)
# Out:
# [[-3.87551016 -7.31229405]
#  [-3.53371397 -8.06872722]
#  [-5.31390009 -6.04107791]
#  ...
#  [-0.16507849 -6.43015525]
#  [-4.34834213 -7.00728222]
#  [-2.13333118 -7.23296553]]
# (10000, 2)

# %%
y
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
@dataclass
class GaussianNaiveBayes:
    X: np.matrix
    y: np.array
    
    def __post_init__(self):
        self.dataSplit()
        self.fit()

    def dataSplit(self):
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(X, y, test_size = 0.3)

    def fitDistribution(self, data):
        mean = np.mean(data)
        std = np.std(data)
        dist = norm(mean, std)
        return dist
    
    def posterior(self, data, prior, dist0, dist1):
        return prior * dist0.pdf(data[0]) * dist1.pdf(data[1])
    
    def fit(self):
        X0_data = self.X_train[self.y_train == 0]
        X1_data = self.X_train[self.y_train == 1]
        
        self.prior_0 = len(X0_data) / len(self.X_train)
        self.prior_1 = len(X1_data) / len(self.X_train)
        
        self.dist_X00 = self.fitDistribution(X0_data[:,0])
        self.dist_X01 = self.fitDistribution(X0_data[:,1])
        self.dist_X10 = self.fitDistribution(X1_data[:,0])
        self.dist_X11 = self.fitDistribution(X1_data[:,1])

    def predict(self):
        
        for sample, target in zip(self.X_test, self.y_test):
            py0 = self.posterior(sample, self.prior_0, self.dist_X00, self.dist_X01) 
            py1 = self.posterior(sample, self.prior_1, self.dist_X10, self.dist_X11) 
            
            print("P(y=0|%s) = %f"%(sample,py0))
            print("P(y=1|%s) = %f"%(sample,py1))
            
            print("the point belongs to class{} and predicted{}".format(target, np.argmax([py0,py1])))

# %%
clf = GaussianNaiveBayes(X,y)

# %%
clf.predict()
# Out:
# P(y=0|[-5.16550641 -8.00064212]) = 0.041392
# P(y=1|[-5.16550641 -8.00064212]) = 0.000648
# the point belongs to class0 and predicted0
# P(y=0|[-4.98480064 -8.42190807]) = 0.030365
# P(y=1|[-4.98480064 -8.42190807]) = 0.000458
# the point belongs to class0 and predicted0
# P(y=0|[-5.65855053 -7.96121229]) = 0.025355
# P(y=1|[-5.65855053 -7.96121229]) = 0.000169
# the point belongs to class0 and predicted0
# P(y=0|[-3.73258732 -5.36565476]) = 0.012933
# P(y=1|[-3.73258732 -5.36565476]) = 0.027069
# the point belongs to class0 and predicted1
# P(y=0|[-4.34422167 -7.35097468]) = 0.079587
# P(y=1|[-4.34422167 -7.35097468]) = 0.009618
# the point belongs to class0 and predicted0
# P(y=0|[-1.1079441  -6.05912486]) = 0.000206
# P(y=1|[-1.1079441  -6.05912486]) = 0.024752
# the point belongs to class1 and predicted1
# P(y=0|[-1.55275051 -5.33434747]) = 0.000276
# P(y=1|[-1.55275051 -5.33434747]) = 0.028803
# the point belongs to class1 and predicted1
# P(y=0|[-3.81156336 -5.87670744]) = 0.029982
# P(y=1|[-3.81156336 -5.87670744]) = 0.034536
# the point belongs to class0 and predicted1
# P(y=0|[-2.96092602 -7.03281371]) = 0.029651
# P(y=1|[-2.96092602 -7.03281371]) = 0.056297
# the point belongs to class0 and predicted1
# P(y=0|[-2.00625003 -6.40723152]) = 0.003645
# P(y=1|[-2.00625003 -6.40723152]) = 0.065632
# the point belongs to class1 and predicted1
# P(y=0|[-4.42894647 -6.78773988]) = 0.075036
# P(y=1|[-4.42894647 -6.78773988]) = 0.012758
# the point belongs to class0 and predicted0
# P(y=0|[-5.31253356 -6.95302981]) = 0.050155
# P(y=1|[-5.31253356 -6.95302981]) = 0.001502
# the point belongs to class0 and predicted0
# P(y=0|[-2.5953591  -7.09637912]) = 0.016618
# P(y=1|[-2.5953591  -7.09637912]) = 0.057251
# the point belongs to class1 and predicted1
# P(y=0|[-2.96173373 -6.61863526]) = 0.025729
# P(y=1|[-2.96173373 -6.61863526]) = 0.070202
# the point belongs to class1 and predicted1
# P(y=0|[-4.75092685 -7.2232968 ]) = 0.074914
# P(y=1|[-4.75092685 -7.2232968 ]) = 0.004872
# the point belongs to class0 and predicted0
# P(y=0|[-2.64282031 -6.70521694]) = 0.016257
# P(y=1|[-2.64282031 -6.70521694]) = 0.072564
# the point belongs to class1 and predicted1
# P(y=0|[-3.76935479 -8.051567  ]) = 0.045854
# P(y=1|[-3.76935479 -8.051567  ]) = 0.008448
# the point belongs to class1 and predicted0
# P(y=0|[-2.90287131 -5.95800789]) = 0.013176
# P(y=1|[-2.90287131 -5.95800789]) = 0.071640
# the point belongs to class0 and predicted1
# P(y=0|[-4.75732403 -6.76139811]) = 0.068817
# P(y=1|[-4.75732403 -6.76139811]) = 0.006635
# the point belongs to class0 and predicted0
# P(y=0|[-4.0653155  -6.98812108]) = 0.076078
# P(y=1|[-4.0653155  -6.98812108]) = 0.020836
# the point belongs to class0 and predicted0
# P(y=0|[-4.24982976 -4.71681733]) = 0.003934
# P(y=1|[-4.24982976 -4.71681733]) = 0.005834
# the point belongs to class0 and predicted1
# P(y=0|[-5.92975995 -8.89513344]) = 0.005276
# P(y=1|[-5.92975995 -8.89513344]) = 0.000010
# the point belongs to class0 and predicted0
# P(y=0|[-4.04581935 -5.98903119]) = 0.038205
# P(y=1|[-4.04581935 -5.98903119]) = 0.026172
# the point belongs to class1 and predicted0
# P(y=0|[-2.59796143 -6.66991636]) = 0.014767
# P(y=1|[-2.59796143 -6.66991636]) = 0.073650
# the point belongs to class1 and predicted1
# P(y=0|[-4.66124304 -5.64067905]) = 0.023953
# P(y=1|[-4.66124304 -5.64067905]) = 0.007407
# the point belongs to class0 and predicted0
# P(y=0|[-3.34698855 -6.89005443]) = 0.046137
# P(y=1|[-3.34698855 -6.89005443]) = 0.049835
# the point belongs to class0 and predicted1
# P(y=0|[-5.05490621 -7.11630714]) = 0.063480
# P(y=1|[-5.05490621 -7.11630714]) = 0.002623
# the point belongs to class0 and predicted0
# P(y=0|[-5.0683029 -4.6167656]) = 0.002398
# P(y=1|[-5.0683029 -4.6167656]) = 0.000893
# the point belongs to class0 and predicted0
# P(y=0|[-3.88872148 -6.82649364]) = 0.068042
# P(y=1|[-3.88872148 -6.82649364]) = 0.029476
# the point belongs to class0 and predicted0
# P(y=0|[-3.40353268 -8.89784303]) = 0.011374
# P(y=1|[-3.40353268 -8.89784303]) = 0.001945
# the point belongs to class0 and predicted0
# P(y=0|[-3.6658928  -8.59837037]) = 0.022757
# P(y=1|[-3.6658928  -8.59837037]) = 0.003148
# the point belongs to class0 and predicted0
# P(y=0|[-2.75335254 -5.10733664]) = 0.002585
# P(y=1|[-2.75335254 -5.10733664]) = 0.039220
# the point belongs to class1 and predicted1
# P(y=0|[-2.28979053 -7.9800988 ]) = 0.006627
# P(y=1|[-2.28979053 -7.9800988 ]) = 0.018207
# the point belongs to class1 and predicted1
# P(y=0|[-2.86029467 -7.26511391]) = 0.025705
# P(y=1|[-2.86029467 -7.26511391]) = 0.047651
# the point belongs to class1 and predicted1
# P(y=0|[-4.26461694 -6.93127563]) = 0.078244
# P(y=1|[-4.26461694 -6.93127563]) = 0.015753
# the point belongs to class1 and predicted0
# P(y=0|[-0.50036056 -8.09695677]) = 0.000028
# P(y=1|[-0.50036056 -8.09695677]) = 0.001646
# the point belongs to class1 and predicted1
# P(y=0|[-2.64732845 -7.65633886]) = 0.016220
# P(y=1|[-2.64732845 -7.65633886]) = 0.031242
# the point belongs to class1 and predicted1
# P(y=0|[-1.77621886 -6.49514211]) = 0.002186
# P(y=1|[-1.77621886 -6.49514211]) = 0.054776
# the point belongs to class1 and predicted1
# P(y=0|[-2.46766697 -6.7017528 ]) = 0.011784
# P(y=1|[-2.46766697 -6.7017528 ]) = 0.072068
# the point belongs to class1 and predicted1
# P(y=0|[-5.11843396 -6.37403712]) = 0.044170
# P(y=1|[-5.11843396 -6.37403712]) = 0.003127
# the point belongs to class0 and predicted0
# P(y=0|[-2.04485746 -5.64681254]) = 0.001670
# P(y=1|[-2.04485746 -5.64681254]) = 0.055156
# the point belongs to class1 and predicted1
# P(y=0|[-3.725757 -5.588788]) = 0.018804
# P(y=1|[-3.725757 -5.588788]) = 0.032642
# the point belongs to class1 and predicted1
# P(y=0|[-4.08470885 -6.65709708]) = 0.068175
# P(y=1|[-4.08470885 -6.65709708]) = 0.024124
# the point belongs to class1 and predicted0
# P(y=0|[-1.28116321 -4.5618633 ]) = 0.000022
# P(y=1|[-1.28116321 -4.5618633 ]) = 0.007435
# the point belongs to class1 and predicted1
# P(y=0|[-2.14997982 -6.30267476]) = 0.004664
# P(y=1|[-2.14997982 -6.30267476]) = 0.071359
# the point belongs to class1 and predicted1
# P(y=0|[-2.00334115 -6.82755538]) = 0.004569
# P(y=1|[-2.00334115 -6.82755538]) = 0.057102
# the point belongs to class1 and predicted1
# P(y=0|[-1.93205491 -6.07738266]) = 0.002241
# P(y=1|[-1.93205491 -6.07738266]) = 0.061645
# the point belongs to class1 and predicted1
# P(y=0|[-1.71903591 -6.41648341]) = 0.001776
# P(y=1|[-1.71903591 -6.41648341]) = 0.052804
# the point belongs to class1 and predicted1
# P(y=0|[-3.386159   -6.65836941]) = 0.043777
# P(y=1|[-3.386159   -6.65836941]) = 0.054054
# the point belongs to class0 and predicted1
# P(y=0|[-2.87024845 -3.10106102]) = 0.000007
# P(y=1|[-2.87024845 -3.10106102]) = 0.000496
# the point belongs to class1 and predicted1
# P(y=0|[-2.82659245 -5.12193227]) = 0.002993
# P(y=1|[-2.82659245 -5.12193227]) = 0.039335
# the point belongs to class1 and predicted1
# P(y=0|[-2.03647726 -5.21121402]) = 0.000766
# P(y=1|[-2.03647726 -5.21121402]) = 0.037880
# the point belongs to class1 and predicted1
# P(y=0|[-4.7287149  -5.88610728]) = 0.033104
# P(y=1|[-4.7287149  -5.88610728]) = 0.007287
# the point belongs to class1 and predicted0
# P(y=0|[-2.0830106  -6.57322106]) = 0.004886
# P(y=1|[-2.0830106  -6.57322106]) = 0.066307
# the point belongs to class1 and predicted1
# P(y=0|[-3.75295495 -5.72872867]) = 0.023648
# P(y=1|[-3.75295495 -5.72872867]) = 0.034514
# the point belongs to class0 and predicted1
# P(y=0|[-3.06959123 -7.16768229]) = 0.034711
# P(y=1|[-3.06959123 -7.16768229]) = 0.048238
# the point belongs to class1 and predicted1
# P(y=0|[-3.36552104 -5.36578442]) = 0.009562
# P(y=1|[-3.36552104 -5.36578442]) = 0.038589
# the point belongs to class1 and predicted1
# P(y=0|[-3.38875193 -6.8071217 ]) = 0.046848
# P(y=1|[-3.38875193 -6.8071217 ]) = 0.050513
# the point belongs to class0 and predicted1
# P(y=0|[-4.32016007 -6.0009523 ]) = 0.040738
# P(y=1|[-4.32016007 -6.0009523 ]) = 0.016877
# the point belongs to class0 and predicted0
# P(y=0|[-2.40192444 -7.82978291]) = 0.009305
# P(y=1|[-2.40192444 -7.82978291]) = 0.023859
# the point belongs to class1 and predicted1
# P(y=0|[-4.42889317 -6.21696235]) = 0.051204
# P(y=1|[-4.42889317 -6.21696235]) = 0.014408
# the point belongs to class0 and predicted0
# P(y=0|[-1.68699808 -6.94619547]) = 0.002113
# P(y=1|[-1.68699808 -6.94619547]) = 0.041697
# the point belongs to class1 and predicted1
# P(y=0|[-4.12267408 -7.74362544]) = 0.066633
# P(y=1|[-4.12267408 -7.74362544]) = 0.008512
# the point belongs to class0 and predicted0
# P(y=0|[-0.01089363 -6.38926985]) = 0.000004
# P(y=1|[-0.01089363 -6.38926985]) = 0.002576
# the point belongs to class1 and predicted1
# P(y=0|[-1.67965172 -6.20878886]) = 0.001336
# P(y=1|[-1.67965172 -6.20878886]) = 0.051189
# the point belongs to class1 and predicted1
# P(y=0|[-3.8480776 -6.1206348]) = 0.040724
# P(y=1|[-3.8480776 -6.1206348]) = 0.035382
# the point belongs to class0 and predicted0
# P(y=0|[-5.00195131 -7.87846882]) = 0.051228
# P(y=1|[-5.00195131 -7.87846882]) = 0.001198
# the point belongs to class0 and predicted0
# P(y=0|[-2.6120932  -6.25080698]) = 0.011237
# P(y=1|[-2.6120932  -6.25080698]) = 0.079128
# the point belongs to class1 and predicted1
# P(y=0|[-4.36409307 -7.39862148]) = 0.078828
# P(y=1|[-4.36409307 -7.39862148]) = 0.008817
# the point belongs to class0 and predicted0
# P(y=0|[-1.58685297 -7.21890367]) = 0.001642
# P(y=1|[-1.58685297 -7.21890367]) = 0.030477
# the point belongs to class1 and predicted1
# P(y=0|[-1.18817425 -7.77881523]) = 0.000412
# P(y=1|[-1.18817425 -7.77881523]) = 0.009497
# the point belongs to class1 and predicted1
# P(y=0|[-5.40297994 -7.51128003]) = 0.044240
# P(y=1|[-5.40297994 -7.51128003]) = 0.000691
# the point belongs to class0 and predicted0
# P(y=0|[-2.14002846 -7.24839316]) = 0.006631
# P(y=1|[-2.14002846 -7.24839316]) = 0.044947
# the point belongs to class1 and predicted1
# P(y=0|[-5.52853429 -8.96188591]) = 0.008158
# P(y=1|[-5.52853429 -8.96188591]) = 0.000029
# the point belongs to class1 and predicted0
# P(y=0|[-3.54560992 -6.8891815 ]) = 0.055453
# P(y=1|[-3.54560992 -6.8891815 ]) = 0.042024
# the point belongs to class0 and predicted0
# P(y=0|[-3.67002996 -6.14376024]) = 0.037414
# P(y=1|[-3.67002996 -6.14376024]) = 0.043808
# the point belongs to class1 and predicted1
# P(y=0|[-3.79431667 -6.58723852]) = 0.057926
# P(y=1|[-3.79431667 -6.58723852]) = 0.036685
# the point belongs to class1 and predicted0
# P(y=0|[-1.79846606 -4.75018521]) = 0.000155
# P(y=1|[-1.79846606 -4.75018521]) = 0.017652
# the point belongs to class1 and predicted1
# P(y=0|[-3.6189638  -7.12315709]) = 0.061066
# P(y=1|[-3.6189638  -7.12315709]) = 0.033056
# the point belongs to class0 and predicted0
# P(y=0|[-5.46692912 -7.0825591 ]) = 0.043592
# P(y=1|[-5.46692912 -7.0825591 ]) = 0.000882
# the point belongs to class0 and predicted0
# P(y=0|[-5.69875448 -6.08664985]) = 0.018259
# P(y=1|[-5.69875448 -6.08664985]) = 0.000585
# the point belongs to class0 and predicted0
# P(y=0|[-5.04115109 -6.43662436]) = 0.049006
# P(y=1|[-5.04115109 -6.43662436]) = 0.003773
# the point belongs to class1 and predicted0
# P(y=0|[-3.01470434 -6.41686055]) = 0.024271
# P(y=1|[-3.01470434 -6.41686055]) = 0.071992
# the point belongs to class0 and predicted1
# P(y=0|[-4.23050365 -5.08399119]) = 0.009050
# P(y=1|[-4.23050365 -5.08399119]) = 0.009986
# the point belongs to class1 and predicted1
# P(y=0|[-4.23962832 -7.73989093]) = 0.068234
# P(y=1|[-4.23962832 -7.73989093]) = 0.007090
# the point belongs to class0 and predicted0
# P(y=0|[-3.30139493 -8.42298673]) = 0.020829
# P(y=1|[-3.30139493 -8.42298673]) = 0.006431
# the point belongs to class0 and predicted0
# P(y=0|[-5.40290836 -8.4618184 ]) = 0.020323
# P(y=1|[-5.40290836 -8.4618184 ]) = 0.000139
# the point belongs to class0 and predicted0
# P(y=0|[-4.55179551 -5.34805995]) = 0.015049
# P(y=1|[-4.55179551 -5.34805995]) = 0.007359
# the point belongs to class0 and predicted0
# P(y=0|[-5.32204593 -6.70619073]) = 0.045681
# P(y=1|[-5.32204593 -6.70619073]) = 0.001671
# the point belongs to class0 and predicted0
# P(y=0|[-3.85277619 -5.58975969]) = 0.020275
# P(y=1|[-3.85277619 -5.58975969]) = 0.028009
# the point belongs to class1 and predicted1
# P(y=0|[-1.66042146 -4.55210412]) = 0.000065
# P(y=1|[-1.66042146 -4.55210412]) = 0.011321
# the point belongs to class1 and predicted1
# P(y=0|[-2.37903521 -4.980512  ]) = 0.001000
# P(y=1|[-2.37903521 -4.980512  ]) = 0.033090
# the point belongs to class1 and predicted1
# P(y=0|[-3.07069347 -5.1291865 ]) = 0.004307
# P(y=1|[-3.07069347 -5.1291865 ]) = 0.036384
# the point belongs to class1 and predicted1
# P(y=0|[-2.21531401 -5.99060501]) = 0.003910
# P(y=1|[-2.21531401 -5.99060501]) = 0.070245
# the point belongs to class1 and predicted1
# P(y=0|[-5.49325243 -7.25209978]) = 0.042338
# P(y=1|[-5.49325243 -7.25209978]) = 0.000704
# the point belongs to class0 and predicted0
# P(y=0|[-2.16229007 -5.86840666]) = 0.002989
# P(y=1|[-2.16229007 -5.86840666]) = 0.065777
# the point belongs to class1 and predicted1
# P(y=0|[-3.37125029 -5.6371836 ]) = 0.015143
# P(y=1|[-3.37125029 -5.6371836 ]) = 0.047471
# the point belongs to class1 and predicted1
# P(y=0|[-2.22230437 -6.45249397]) = 0.006160
# P(y=1|[-2.22230437 -6.45249397]) = 0.072602
# the point belongs to class1 and predicted1
# P(y=0|[-3.3646101  -7.35483171]) = 0.048030
# P(y=1|[-3.3646101  -7.35483171]) = 0.033460
# the point belongs to class0 and predicted0
# P(y=0|[-1.75413182 -6.82438993]) = 0.002441
# P(y=1|[-1.75413182 -6.82438993]) = 0.047604
# the point belongs to class1 and predicted1
# P(y=0|[-3.77535813 -8.49002677]) = 0.028368
# P(y=1|[-3.77535813 -8.49002677]) = 0.003541
# the point belongs to class0 and predicted0
# P(y=0|[-1.2971317  -5.33953825]) = 0.000130
# P(y=1|[-1.2971317  -5.33953825]) = 0.021302
# the point belongs to class1 and predicted1
# P(y=0|[-3.08830171 -7.16323733]) = 0.035563
# P(y=1|[-3.08830171 -7.16323733]) = 0.047986
# the point belongs to class1 and predicted1
# P(y=0|[-2.30211186 -6.47871344]) = 0.007434
# P(y=1|[-2.30211186 -6.47871344]) = 0.074290
# the point belongs to class1 and predicted1
# P(y=0|[-2.91649286 -4.76746613]) = 0.001554
# P(y=1|[-2.91649286 -4.76746613]) = 0.023933
# the point belongs to class1 and predicted1
# P(y=0|[-1.41926647 -4.98311333]) = 0.000092
# P(y=1|[-1.41926647 -4.98311333]) = 0.016700
# the point belongs to class1 and predicted1
# P(y=0|[-4.7689779  -6.51885239]) = 0.060211
# P(y=1|[-4.7689779  -6.51885239]) = 0.007039
# the point belongs to class0 and predicted0
# P(y=0|[-3.71715976 -7.84411603]) = 0.052167
# P(y=1|[-3.71715976 -7.84411603]) = 0.012633
# the point belongs to class0 and predicted0
# P(y=0|[-4.1086445  -3.49366998]) = 0.000089
# P(y=1|[-4.1086445  -3.49366998]) = 0.000519
# the point belongs to class1 and predicted1
# P(y=0|[-5.27337918 -5.99876686]) = 0.026780
# P(y=1|[-5.27337918 -5.99876686]) = 0.001999
# the point belongs to class0 and predicted0
# P(y=0|[-4.36586032 -8.13898663]) = 0.050550
# P(y=1|[-4.36586032 -8.13898663]) = 0.002962
# the point belongs to class0 and predicted0
# P(y=0|[-4.67541862 -6.71339173]) = 0.069394
# P(y=1|[-4.67541862 -6.71339173]) = 0.008087
# the point belongs to class0 and predicted0
# P(y=0|[-3.09867734 -6.05262643]) = 0.019271
# P(y=1|[-3.09867734 -6.05262643]) = 0.067931
# the point belongs to class1 and predicted1
# P(y=0|[-5.0007457 -6.4692095]) = 0.051532
# P(y=1|[-5.0007457 -6.4692095]) = 0.004146
# the point belongs to class0 and predicted0
# P(y=0|[-1.86713946 -6.18844683]) = 0.002140
# P(y=1|[-1.86713946 -6.18844683]) = 0.059859
# the point belongs to class0 and predicted1
# P(y=0|[-3.98960879 -7.15478338]) = 0.075379
# P(y=1|[-3.98960879 -7.15478338]) = 0.020433
# the point belongs to class1 and predicted0
# P(y=0|[-2.95461596 -6.18108641]) = 0.018167
# P(y=1|[-2.95461596 -6.18108641]) = 0.073896
# the point belongs to class1 and predicted1
# P(y=0|[-3.52262238 -7.37332468]) = 0.055433
# P(y=1|[-3.52262238 -7.37332468]) = 0.028646
# the point belongs to class0 and predicted0
# P(y=0|[-2.98019977 -8.19709931]) = 0.018129
# P(y=1|[-2.98019977 -8.19709931]) = 0.012070
# the point belongs to class0 and predicted0
# P(y=0|[-6.69264709 -6.37056803]) = 0.003793
# P(y=1|[-6.69264709 -6.37056803]) = 0.000016
# the point belongs to class0 and predicted0
# P(y=0|[-1.69864005 -6.21537462]) = 0.001415
# P(y=1|[-1.69864005 -6.21537462]) = 0.052127
# the point belongs to class1 and predicted1
# P(y=0|[-5.67674319 -5.7601364 ]) = 0.012503
# P(y=1|[-5.67674319 -5.7601364 ]) = 0.000557
# the point belongs to class0 and predicted0
# P(y=0|[-4.71732601 -7.48584319]) = 0.072268
# P(y=1|[-4.71732601 -7.48584319]) = 0.003970
# the point belongs to class0 and predicted0
# P(y=0|[-4.37383691 -7.7805876 ]) = 0.067129
# P(y=1|[-4.37383691 -7.7805876 ]) = 0.005291
# the point belongs to class1 and predicted0
# P(y=0|[-5.44394068 -7.33487577]) = 0.044278
# P(y=1|[-5.44394068 -7.33487577]) = 0.000749
# the point belongs to class0 and predicted0
# P(y=0|[-2.10170295 -7.27362456]) = 0.006065
# P(y=1|[-2.10170295 -7.27362456]) = 0.043049
# the point belongs to class1 and predicted1
# P(y=0|[-3.89983645 -6.62084087]) = 0.062386
# P(y=1|[-3.89983645 -6.62084087]) = 0.031749
# the point belongs to class1 and predicted0
# P(y=0|[-1.70523333 -5.66549766]) = 0.000731
# P(y=1|[-1.70523333 -5.66549766]) = 0.043396
# the point belongs to class1 and predicted1
# P(y=0|[-5.03184998 -6.24102758]) = 0.041898
# P(y=1|[-5.03184998 -6.24102758]) = 0.003900
# the point belongs to class0 and predicted0
# P(y=0|[-3.61154679 -7.75808692]) = 0.051122
# P(y=1|[-3.61154679 -7.75808692]) = 0.016116
# the point belongs to class0 and predicted0
# P(y=0|[-4.34758414 -7.28801007]) = 0.080345
# P(y=1|[-4.34758414 -7.28801007]) = 0.010197
# the point belongs to class1 and predicted0
# P(y=0|[-2.06068124 -5.87858899]) = 0.002404
# P(y=1|[-2.06068124 -5.87858899]) = 0.062783
# the point belongs to class1 and predicted1
# P(y=0|[-2.11945655 -6.53321131]) = 0.005181
# P(y=1|[-2.11945655 -6.53321131]) = 0.068266
# the point belongs to class1 and predicted1
# P(y=0|[-3.56307385 -6.53748057]) = 0.047882
# P(y=1|[-3.56307385 -6.53748057]) = 0.047931
# the point belongs to class0 and predicted1
# P(y=0|[-2.41058016 -7.52863248]) = 0.011038
# P(y=1|[-2.41058016 -7.52863248]) = 0.036216
# the point belongs to class1 and predicted1
# P(y=0|[-5.43623615 -5.88287783]) = 0.019723
# P(y=1|[-5.43623615 -5.88287783]) = 0.001216
# the point belongs to class0 and predicted0
# P(y=0|[-3.98576927 -6.95202927]) = 0.073503
# P(y=1|[-3.98576927 -6.95202927]) = 0.023964
# the point belongs to class1 and predicted0
# P(y=0|[-1.6442567  -8.19948566]) = 0.001134
# P(y=1|[-1.6442567  -8.19948566]) = 0.008102
# the point belongs to class1 and predicted1
# P(y=0|[-3.85659757 -5.77180808]) = 0.026660
# P(y=1|[-3.85659757 -5.77180808]) = 0.031100
# the point belongs to class0 and predicted1
# P(y=0|[-2.73488018 -4.76619778]) = 0.001169
# P(y=1|[-2.73488018 -4.76619778]) = 0.024899
# the point belongs to class1 and predicted1
# P(y=0|[-2.36263788 -7.38266869]) = 0.010458
# P(y=1|[-2.36263788 -7.38266869]) = 0.042439
# the point belongs to class1 and predicted1
# P(y=0|[-2.27009501 -4.31664471]) = 0.000149
# P(y=1|[-2.27009501 -4.31664471]) = 0.010905
# the point belongs to class1 and predicted1
# P(y=0|[-3.24844827 -6.69590669]) = 0.038553
# P(y=1|[-3.24844827 -6.69590669]) = 0.058905
# the point belongs to class0 and predicted1
# P(y=0|[-1.14244417 -6.15265261]) = 0.000254
# P(y=1|[-1.14244417 -6.15265261]) = 0.026515
# the point belongs to class1 and predicted1
# P(y=0|[-2.35094369 -5.85820554]) = 0.004408
# P(y=1|[-2.35094369 -5.85820554]) = 0.069987
# the point belongs to class1 and predicted1
# P(y=0|[-5.91442473 -5.58875047]) = 0.006856
# P(y=1|[-5.91442473 -5.58875047]) = 0.000231
# the point belongs to class0 and predicted0
# P(y=0|[-3.93057922 -7.45204415]) = 0.070721
# P(y=1|[-3.93057922 -7.45204415]) = 0.016435
# the point belongs to class1 and predicted0
# P(y=0|[-4.10711471 -5.5462008 ]) = 0.020865
# P(y=1|[-4.10711471 -5.5462008 ]) = 0.018994
# the point belongs to class1 and predicted0
# P(y=0|[-4.71737248 -7.26674362]) = 0.075613
# P(y=1|[-4.71737248 -7.26674362]) = 0.005029
# the point belongs to class0 and predicted0
# P(y=0|[-3.42565657 -6.19677524]) = 0.032256
# P(y=1|[-3.42565657 -6.19677524]) = 0.055793
# the point belongs to class0 and predicted1
# P(y=0|[-3.2052989 -5.8055743]) = 0.016148
# P(y=1|[-3.2052989 -5.8055743]) = 0.058606
# the point belongs to class1 and predicted1
# P(y=0|[-4.11233569 -6.69797943]) = 0.070082
# P(y=1|[-4.11233569 -6.69797943]) = 0.022765
# the point belongs to class0 and predicted0
# P(y=0|[-2.28311851 -6.27721079]) = 0.006087
# P(y=1|[-2.28311851 -6.27721079]) = 0.075192
# the point belongs to class1 and predicted1
# P(y=0|[-3.54387496 -5.46751393]) = 0.013470
# P(y=1|[-3.54387496 -5.46751393]) = 0.036082
# the point belongs to class0 and predicted1
# P(y=0|[-3.88778369 -6.60266979]) = 0.061402
# P(y=1|[-3.88778369 -6.60266979]) = 0.032446
# the point belongs to class1 and predicted0
# P(y=0|[-4.06112616 -5.76804098]) = 0.028835
# P(y=1|[-4.06112616 -5.76804098]) = 0.023391
# the point belongs to class1 and predicted0
# P(y=0|[-3.1519637  -7.08600589]) = 0.038390
# P(y=1|[-3.1519637  -7.08600589]) = 0.049471
# the point belongs to class0 and predicted1
# P(y=0|[-3.57276819 -6.8152916 ]) = 0.055372
# P(y=1|[-3.57276819 -6.8152916 ]) = 0.042654
# the point belongs to class0 and predicted0
# P(y=0|[-0.35390176 -7.67541008]) = 0.000021
# P(y=1|[-0.35390176 -7.67541008]) = 0.002321
# the point belongs to class1 and predicted1
# P(y=0|[-2.3560977  -7.02670698]) = 0.010448
# P(y=1|[-2.3560977  -7.02670698]) = 0.058569
# the point belongs to class1 and predicted1
# P(y=0|[-3.39342401 -7.44155358]) = 0.048457
# P(y=1|[-3.39342401 -7.44155358]) = 0.029726
# the point belongs to class0 and predicted0
# P(y=0|[-5.26558432 -6.73895266]) = 0.048883
# P(y=1|[-5.26558432 -6.73895266]) = 0.001924
# the point belongs to class0 and predicted0
# P(y=0|[-3.86644594 -7.35615086]) = 0.070180
# P(y=1|[-3.86644594 -7.35615086]) = 0.019893
# the point belongs to class0 and predicted0
# P(y=0|[-4.43078596 -6.41019497]) = 0.060439
# P(y=1|[-4.43078596 -6.41019497]) = 0.014286
# the point belongs to class0 and predicted0
# P(y=0|[-1.39259225 -4.98170664]) = 0.000085
# P(y=1|[-1.39259225 -4.98170664]) = 0.016137
# the point belongs to class1 and predicted1
# P(y=0|[-4.85047087 -7.52665499]) = 0.067365
# P(y=1|[-4.85047087 -7.52665499]) = 0.002810
# the point belongs to class0 and predicted0
# P(y=0|[-2.18966469 -4.63119115]) = 0.000293
# P(y=1|[-2.18966469 -4.63119115]) = 0.018627
# the point belongs to class1 and predicted1
# P(y=0|[-2.45673458 -6.49488025]) = 0.010249
# P(y=1|[-2.45673458 -6.49488025]) = 0.076692
# the point belongs to class1 and predicted1
# P(y=0|[ -7.45892352 -10.48564711]) = 0.000003
# P(y=1|[ -7.45892352 -10.48564711]) = 0.000000
# the point belongs to class0 and predicted0
# P(y=0|[-3.68541157 -7.49958525]) = 0.060731
# P(y=1|[-3.68541157 -7.49958525]) = 0.021007
# the point belongs to class0 and predicted0
# P(y=0|[-2.75866553 -5.32996433]) = 0.004031
# P(y=1|[-2.75866553 -5.32996433]) = 0.049620
# the point belongs to class1 and predicted1
# P(y=0|[-5.31810815 -8.50113563]) = 0.021020
# P(y=1|[-5.31810815 -8.50113563]) = 0.000162
# the point belongs to class0 and predicted0
# P(y=0|[-3.92268629 -7.51527076]) = 0.069088
# P(y=1|[-3.92268629 -7.51527076]) = 0.015411
# the point belongs to class0 and predicted0
# P(y=0|[-4.27084174 -7.40059309]) = 0.078449
# P(y=1|[-4.27084174 -7.40059309]) = 0.010357
# the point belongs to class0 and predicted0
# P(y=0|[-4.34359729 -7.55228121]) = 0.075192
# P(y=1|[-4.34359729 -7.55228121]) = 0.007632
# the point belongs to class0 and predicted0
# P(y=0|[-3.30596607 -6.02107609]) = 0.023714
# P(y=1|[-3.30596607 -6.02107609]) = 0.059367
# the point belongs to class1 and predicted1
# P(y=0|[-3.87034059 -4.09559505]) = 0.000626
# P(y=1|[-3.87034059 -4.09559505]) = 0.003218
# the point belongs to class1 and predicted1
# P(y=0|[-3.51425693 -6.92065457]) = 0.054461
# P(y=1|[-3.51425693 -6.92065457]) = 0.042463
# the point belongs to class1 and predicted0
# P(y=0|[-2.61334285 -7.4448125 ]) = 0.016566
# P(y=1|[-2.61334285 -7.4448125 ]) = 0.040760
# the point belongs to class0 and predicted1
# P(y=0|[-1.83154531 -6.15899813]) = 0.001898
# P(y=1|[-1.83154531 -6.15899813]) = 0.058054
# the point belongs to class1 and predicted1
# P(y=0|[-4.03577446 -7.9687066 ]) = 0.055669
# P(y=1|[-4.03577446 -7.9687066 ]) = 0.006836
# the point belongs to class0 and predicted0
# P(y=0|[-2.2462961  -8.02435567]) = 0.005825
# P(y=1|[-2.2462961  -8.02435567]) = 0.016639
# the point belongs to class1 and predicted1
# P(y=0|[-5.06790793 -6.0711609 ]) = 0.034383
# P(y=1|[-5.06790793 -6.0711609 ]) = 0.003486
# the point belongs to class0 and predicted0
# P(y=0|[-2.54182294 -6.5339635 ]) = 0.012344
# P(y=1|[-2.54182294 -6.5339635 ]) = 0.076699
# the point belongs to class1 and predicted1
# P(y=0|[-2.03409858 -6.19088722]) = 0.003223
# P(y=1|[-2.03409858 -6.19088722]) = 0.066887
# the point belongs to class1 and predicted1
# P(y=0|[-5.55968778 -6.03819141]) = 0.020669
# P(y=1|[-5.55968778 -6.03819141]) = 0.000889
# the point belongs to class0 and predicted0
# P(y=0|[-5.05785432 -8.08212422]) = 0.041816
# P(y=1|[-5.05785432 -8.08212422]) = 0.000741
# the point belongs to class0 and predicted0
# P(y=0|[-3.34967272 -8.400739  ]) = 0.022527
# P(y=1|[-3.34967272 -8.400739  ]) = 0.006504
# the point belongs to class0 and predicted0
# P(y=0|[-1.09041523 -4.34487638]) = 0.000007
# P(y=1|[-1.09041523 -4.34487638]) = 0.003805
# the point belongs to class1 and predicted1
# P(y=0|[-2.39885168 -4.99440928]) = 0.001072
# P(y=1|[-2.39885168 -4.99440928]) = 0.033834
# the point belongs to class1 and predicted1
# P(y=0|[-1.43682746 -5.65021805]) = 0.000335
# P(y=1|[-1.43682746 -5.65021805]) = 0.032423
# the point belongs to class1 and predicted1
# P(y=0|[-1.13728955 -5.95889292]) = 0.000201
# P(y=1|[-1.13728955 -5.95889292]) = 0.025165
# the point belongs to class1 and predicted1
# P(y=0|[-1.71670217 -6.56351489]) = 0.001951
# P(y=1|[-1.71670217 -6.56351489]) = 0.051162
# the point belongs to class1 and predicted1
# P(y=0|[-2.10684416 -5.1967289 ]) = 0.000876
# P(y=1|[-2.10684416 -5.1967289 ]) = 0.038739
# the point belongs to class1 and predicted1
# P(y=0|[-4.36929311 -6.16670386]) = 0.048844
# P(y=1|[-4.36929311 -6.16670386]) = 0.015994
# the point belongs to class0 and predicted0
# P(y=0|[-3.51820915 -6.02244617]) = 0.029129
# P(y=1|[-3.51820915 -6.02244617]) = 0.049838
# the point belongs to class0 and predicted1
# P(y=0|[-1.39549891 -6.15615556]) = 0.000563
# P(y=1|[-1.39549891 -6.15615556]) = 0.037407
# the point belongs to class1 and predicted1
# P(y=0|[-2.32704072 -7.48155616]) = 0.009476
# P(y=1|[-2.32704072 -7.48155616]) = 0.037582
# the point belongs to class1 and predicted1
# P(y=0|[-2.0514818  -6.70692576]) = 0.004876
# P(y=1|[-2.0514818  -6.70692576]) = 0.062202
# the point belongs to class1 and predicted1
# P(y=0|[-3.8318286  -5.60547802]) = 0.020555
# P(y=1|[-3.8318286  -5.60547802]) = 0.029072
# the point belongs to class1 and predicted1
# P(y=0|[-4.29796543 -7.04780412]) = 0.080136
# P(y=1|[-4.29796543 -7.04780412]) = 0.013719
# the point belongs to class1 and predicted0
# P(y=0|[-3.92412741 -7.30191274]) = 0.072749
# P(y=1|[-3.92412741 -7.30191274]) = 0.019499
# the point belongs to class0 and predicted0
# P(y=0|[-4.506867   -7.18538538]) = 0.080077
# P(y=1|[-4.506867   -7.18538538]) = 0.008350
# the point belongs to class0 and predicted0
# P(y=0|[-1.47064727 -6.35981771]) = 0.000848
# P(y=1|[-1.47064727 -6.35981771]) = 0.041156
# the point belongs to class1 and predicted1
# P(y=0|[-2.87962871 -6.82967779]) = 0.025084
# P(y=1|[-2.87962871 -6.82967779]) = 0.065806
# the point belongs to class1 and predicted1
# P(y=0|[-2.44826928 -7.22731449]) = 0.012652
# P(y=1|[-2.44826928 -7.22731449]) = 0.050499
# the point belongs to class1 and predicted1
# P(y=0|[-4.1961563  -7.97669659]) = 0.057580
# P(y=1|[-4.1961563  -7.97669659]) = 0.005266
# the point belongs to class0 and predicted0
# P(y=0|[-5.76183065 -4.319525  ]) = 0.000513
# P(y=1|[-5.76183065 -4.319525  ]) = 0.000071
# the point belongs to class1 and predicted0
# P(y=0|[-4.78756577 -6.3810859 ]) = 0.054087
# P(y=1|[-4.78756577 -6.3810859 ]) = 0.006906
# the point belongs to class0 and predicted0
# P(y=0|[-4.20426627 -7.41526461]) = 0.077513
# P(y=1|[-4.20426627 -7.41526461]) = 0.011386
# the point belongs to class0 and predicted0
# P(y=0|[-2.89962052 -7.70219588]) = 0.023767
# P(y=1|[-2.89962052 -7.70219588]) = 0.028058
# the point belongs to class1 and predicted1
# P(y=0|[-2.98116895 -7.08036399]) = 0.030674
# P(y=1|[-2.98116895 -7.08036399]) = 0.053880
# the point belongs to class1 and predicted1
# P(y=0|[-1.48584319 -4.84617876]) = 0.000082
# P(y=1|[-1.48584319 -4.84617876]) = 0.014983
# the point belongs to class1 and predicted1
# P(y=0|[-4.58242373 -7.38347784]) = 0.077208
# P(y=1|[-4.58242373 -7.38347784]) = 0.005911
# the point belongs to class0 and predicted0
# P(y=0|[-2.2978572 -6.588668 ]) = 0.007904
# P(y=1|[-2.2978572 -6.588668 ]) = 0.072229
# the point belongs to class1 and predicted1
# P(y=0|[-4.11032084 -5.52484488]) = 0.020164
# P(y=1|[-4.11032084 -5.52484488]) = 0.018602
# the point belongs to class1 and predicted0
# P(y=0|[-4.42636925 -6.60901598]) = 0.068964
# P(y=1|[-4.42636925 -6.60901598]) = 0.013787
# the point belongs to class0 and predicted0
# P(y=0|[-2.03273847 -7.25575619]) = 0.005177
# P(y=1|[-2.03273847 -7.25575619]) = 0.042187
# the point belongs to class1 and predicted1
# P(y=0|[-2.85014848 -7.77705549]) = 0.021139
# P(y=1|[-2.85014848 -7.77705549]) = 0.025540
# the point belongs to class1 and predicted1
# P(y=0|[-4.12062463 -6.59848264]) = 0.066665
# P(y=1|[-4.12062463 -6.59848264]) = 0.023290
# the point belongs to class0 and predicted0
# P(y=0|[-1.5122001  -5.59604161]) = 0.000384
# P(y=1|[-1.5122001  -5.59604161]) = 0.034116
# the point belongs to class1 and predicted1
# P(y=0|[-3.51147015 -6.45057983]) = 0.043238
# P(y=1|[-3.51147015 -6.45057983]) = 0.051253
# the point belongs to class1 and predicted1
# P(y=0|[-5.35176577 -6.35015305]) = 0.035279
# P(y=1|[-5.35176577 -6.35015305]) = 0.001675
# the point belongs to class0 and predicted0
# P(y=0|[-3.19189426 -5.69435386]) = 0.013567
# P(y=1|[-3.19189426 -5.69435386]) = 0.055683
# the point belongs to class1 and predicted1
# P(y=0|[-2.29823602 -7.02145112]) = 0.009268
# P(y=1|[-2.29823602 -7.02145112]) = 0.057851
# the point belongs to class1 and predicted1
# P(y=0|[-5.86357704 -7.48436142]) = 0.024722
# P(y=1|[-5.86357704 -7.48436142]) = 0.000172
# the point belongs to class0 and predicted0
# P(y=0|[-4.27684948 -6.44747349]) = 0.062039
# P(y=1|[-4.27684948 -6.44747349]) = 0.018708
# the point belongs to class0 and predicted0
# P(y=0|[-3.17788542 -6.71642225]) = 0.035857
# P(y=1|[-3.17788542 -6.71642225]) = 0.061032
# the point belongs to class1 and predicted1
# P(y=0|[-3.59438662 -5.92830771]) = 0.027692
# P(y=1|[-3.59438662 -5.92830771]) = 0.044948
# the point belongs to class1 and predicted1
# P(y=0|[-4.39542707 -8.83209958]) = 0.020257
# P(y=1|[-4.39542707 -8.83209958]) = 0.000620
# the point belongs to class0 and predicted0
# P(y=0|[-2.51912083 -6.5491265 ]) = 0.011949
# P(y=1|[-2.51912083 -6.5491265 ]) = 0.076281
# the point belongs to class1 and predicted1
# P(y=0|[-2.67673916 -4.11593501]) = 0.000179
# P(y=1|[-2.67673916 -4.11593501]) = 0.007615
# the point belongs to class1 and predicted1
# P(y=0|[-2.53569301 -6.07255909]) = 0.008173
# P(y=1|[-2.53569301 -6.07255909]) = 0.077218
# the point belongs to class0 and predicted1
# P(y=0|[-1.96859938 -7.95443853]) = 0.003275
# P(y=1|[-1.96859938 -7.95443853]) = 0.016279
# the point belongs to class1 and predicted1
# P(y=0|[-4.57352318 -7.01912086]) = 0.078240
# P(y=1|[-4.57352318 -7.01912086]) = 0.008372
# the point belongs to class0 and predicted0
# P(y=0|[-5.30671204 -7.73826245]) = 0.043929
# P(y=1|[-5.30671204 -7.73826245]) = 0.000670
# the point belongs to class0 and predicted0
# P(y=0|[-5.25487525 -6.19168385]) = 0.033529
# P(y=1|[-5.25487525 -6.19168385]) = 0.002181
# the point belongs to class0 and predicted0
# P(y=0|[-1.82173464 -6.46634615]) = 0.002411
# P(y=1|[-1.82173464 -6.46634615]) = 0.057168
# the point belongs to class1 and predicted1
# P(y=0|[-3.2021528  -7.20906042]) = 0.040886
# P(y=1|[-3.2021528  -7.20906042]) = 0.043250
# the point belongs to class1 and predicted1
# P(y=0|[-2.03081513 -7.89117702]) = 0.003986
# P(y=1|[-2.03081513 -7.89117702]) = 0.018740
# the point belongs to class1 and predicted1
# P(y=0|[-4.4513484  -5.39137547]) = 0.016501
# P(y=1|[-4.4513484  -5.39137547]) = 0.009298
# the point belongs to class0 and predicted0
# P(y=0|[-6.68444405 -6.44780533]) = 0.004101
# P(y=1|[-6.68444405 -6.44780533]) = 0.000016
# the point belongs to class0 and predicted0
# P(y=0|[-3.82431141 -5.8560498 ]) = 0.029390
# P(y=1|[-3.82431141 -5.8560498 ]) = 0.033702
# the point belongs to class0 and predicted1
# P(y=0|[ 0.10510795 -6.97739039]) = 0.000003
# P(y=1|[ 0.10510795 -6.97739039]) = 0.001495
# the point belongs to class1 and predicted1
# P(y=0|[-5.17667381 -6.50448411]) = 0.046410
# P(y=1|[-5.17667381 -6.50448411]) = 0.002636
# the point belongs to class1 and predicted0
# P(y=0|[-4.54670419 -9.26781223]) = 0.008767
# P(y=1|[-4.54670419 -9.26781223]) = 0.000141
# the point belongs to class0 and predicted0
# P(y=0|[-3.99260069 -5.70736124]) = 0.025819
# P(y=1|[-3.99260069 -5.70736124]) = 0.024998
# the point belongs to class1 and predicted0
# P(y=0|[-4.7851884  -6.85865625]) = 0.070464
# P(y=1|[-4.7851884  -6.85865625]) = 0.005932
# the point belongs to class0 and predicted0
# P(y=0|[-3.62714882 -6.69358666]) = 0.054889
# P(y=1|[-3.62714882 -6.69358666]) = 0.042697
# the point belongs to class0 and predicted0
# P(y=0|[-2.74502238 -4.97322294]) = 0.001915
# P(y=1|[-2.74502238 -4.97322294]) = 0.033266
# the point belongs to class1 and predicted1
# P(y=0|[-0.89694006 -5.90974062]) = 0.000084
# P(y=1|[-0.89694006 -5.90974062]) = 0.016778
# the point belongs to class1 and predicted1
# P(y=0|[-3.39663933 -7.56793453]) = 0.046593
# P(y=1|[-3.39663933 -7.56793453]) = 0.025454
# the point belongs to class1 and predicted0
# P(y=0|[-2.93918038 -5.92012803]) = 0.013258
# P(y=1|[-2.93918038 -5.92012803]) = 0.069877
# the point belongs to class1 and predicted1
# P(y=0|[-5.13148131 -8.00570793]) = 0.042345
# P(y=1|[-5.13148131 -8.00570793]) = 0.000702
# the point belongs to class0 and predicted0
# P(y=0|[-5.73954642 -8.24832536]) = 0.017369
# P(y=1|[-5.73954642 -8.24832536]) = 0.000078
# the point belongs to class0 and predicted0
# P(y=0|[-3.74217765 -7.90038822]) = 0.050952
# P(y=1|[-3.74217765 -7.90038822]) = 0.011235
# the point belongs to class0 and predicted0
# P(y=0|[-2.99196088 -6.11659787]) = 0.017922
# P(y=1|[-2.99196088 -6.11659787]) = 0.072214
# the point belongs to class0 and predicted1
# P(y=0|[-5.25722056 -6.55677521]) = 0.044774
# P(y=1|[-5.25722056 -6.55677521]) = 0.002100
# the point belongs to class0 and predicted0
# P(y=0|[-3.4336006  -6.80634479]) = 0.048901
# P(y=1|[-3.4336006  -6.80634479]) = 0.048698
# the point belongs to class0 and predicted0
# P(y=0|[-2.1154193  -4.89180411]) = 0.000466
# P(y=1|[-2.1154193  -4.89180411]) = 0.026712
# the point belongs to class1 and predicted1
# P(y=0|[-1.10579714 -6.03260365]) = 0.000198
# P(y=1|[-1.10579714 -6.03260365]) = 0.024515
# the point belongs to class1 and predicted1
# P(y=0|[-3.84906791 -6.9379199 ]) = 0.068887
# P(y=1|[-3.84906791 -6.9379199 ]) = 0.029052
# the point belongs to class0 and predicted0
# P(y=0|[-1.98185615 -5.71793832]) = 0.001599
# P(y=1|[-1.98185615 -5.71793832]) = 0.055428
# the point belongs to class1 and predicted1
# P(y=0|[-4.52288502 -6.23274264]) = 0.051425
# P(y=1|[-4.52288502 -6.23274264]) = 0.012052
# the point belongs to class0 and predicted0
# P(y=0|[-4.1845595  -6.61694986]) = 0.068289
# P(y=1|[-4.1845595  -6.61694986]) = 0.020928
# the point belongs to class1 and predicted0
# P(y=0|[-2.4257362  -6.71530064]) = 0.010933
# P(y=1|[-2.4257362  -6.71530064]) = 0.071189
# the point belongs to class1 and predicted1
# P(y=0|[-4.89793901 -7.39493528]) = 0.068308
# P(y=1|[-4.89793901 -7.39493528]) = 0.002935
# the point belongs to class0 and predicted0
# P(y=0|[-0.94441246 -5.21106861]) = 0.000032
# P(y=1|[-0.94441246 -5.21106861]) = 0.010995
# the point belongs to class1 and predicted1
# P(y=0|[-4.03988552 -6.8485743 ]) = 0.072859
# P(y=1|[-4.03988552 -6.8485743 ]) = 0.023608
# the point belongs to class1 and predicted0
# P(y=0|[-3.46249121 -7.48280338]) = 0.051107
# P(y=1|[-3.46249121 -7.48280338]) = 0.026730
# the point belongs to class0 and predicted0
# P(y=0|[-3.41782756 -5.36295938]) = 0.010014
# P(y=1|[-3.41782756 -5.36295938]) = 0.036902
# the point belongs to class0 and predicted1
# P(y=0|[-4.86706999 -7.77886377]) = 0.059134
# P(y=1|[-4.86706999 -7.77886377]) = 0.001922
# the point belongs to class1 and predicted0
# P(y=0|[-3.99609722 -7.78921229]) = 0.062365
# P(y=1|[-3.99609722 -7.78921229]) = 0.009609
# the point belongs to class0 and predicted0
# P(y=0|[-2.37562103 -7.29282959]) = 0.010898
# P(y=1|[-2.37562103 -7.29282959]) = 0.046746
# the point belongs to class1 and predicted1
# P(y=0|[-4.45800095 -8.06161288]) = 0.054090
# P(y=1|[-4.45800095 -8.06161288]) = 0.002872
# the point belongs to class0 and predicted0
# P(y=0|[-2.61761998 -6.00790404]) = 0.008807
# P(y=1|[-2.61761998 -6.00790404]) = 0.076161
# the point belongs to class1 and predicted1
# P(y=0|[-2.42652454 -6.85437953]) = 0.011555
# P(y=1|[-2.42652454 -6.85437953]) = 0.066480
# the point belongs to class1 and predicted1
# P(y=0|[-3.88039394 -7.5807299 ]) = 0.066078
# P(y=1|[-3.88039394 -7.5807299 ]) = 0.015019
# the point belongs to class1 and predicted0
# P(y=0|[-4.31762498 -7.04963322]) = 0.080243
# P(y=1|[-4.31762498 -7.04963322]) = 0.013240
# the point belongs to class0 and predicted0
# P(y=0|[-2.82038155 -5.82190728]) = 0.009762
# P(y=1|[-2.82038155 -5.82190728]) = 0.069396
# the point belongs to class1 and predicted1
# P(y=0|[-2.16424571 -5.43351905]) = 0.001548
# P(y=1|[-2.16424571 -5.43351905]) = 0.050025
# the point belongs to class1 and predicted1
# P(y=0|[-5.29855194 -7.54827945]) = 0.048445
# P(y=1|[-5.29855194 -7.54827945]) = 0.000884
# the point belongs to class0 and predicted0
# P(y=0|[-3.74066119 -5.4079884 ]) = 0.014021
# P(y=1|[-3.74066119 -5.4079884 ]) = 0.027852
# the point belongs to class0 and predicted1
# P(y=0|[-5.95904874 -7.59929872]) = 0.020401
# P(y=1|[-5.95904874 -7.59929872]) = 0.000108
# the point belongs to class0 and predicted0
# P(y=0|[-1.74785981 -7.56202306]) = 0.002360
# P(y=1|[-1.74785981 -7.56202306]) = 0.024410
# the point belongs to class0 and predicted1
# P(y=0|[-5.2881195  -5.96419314]) = 0.025351
# P(y=1|[-5.2881195  -5.96419314]) = 0.001900
# the point belongs to class0 and predicted0
# P(y=0|[-4.48617153 -7.30800775]) = 0.079547
# P(y=1|[-4.48617153 -7.30800775]) = 0.007734
# the point belongs to class0 and predicted0
# P(y=0|[-4.18550008 -8.42372958]) = 0.036223
# P(y=1|[-4.18550008 -8.42372958]) = 0.002295
# the point belongs to class1 and predicted0
# P(y=0|[-3.79039394 -6.76535457]) = 0.063123
# P(y=1|[-3.79039394 -6.76535457]) = 0.034414
# the point belongs to class1 and predicted0
# P(y=0|[-4.04683718 -4.78166206]) = 0.004406
# P(y=1|[-4.04683718 -4.78166206]) = 0.008870
# the point belongs to class1 and predicted1
# P(y=0|[-1.15259831 -7.50020974]) = 0.000418
# P(y=1|[-1.15259831 -7.50020974]) = 0.013101
# the point belongs to class1 and predicted1
# P(y=0|[-3.8457123  -6.47470948]) = 0.055440
# P(y=1|[-3.8457123  -6.47470948]) = 0.035364
# the point belongs to class0 and predicted0
# P(y=0|[-6.75328336 -8.43938962]) = 0.002017
# P(y=1|[-6.75328336 -8.43938962]) = 0.000001
# the point belongs to class0 and predicted0
# P(y=0|[-2.32936693 -7.3306175 ]) = 0.009867
# P(y=1|[-2.32936693 -7.3306175 ]) = 0.044460
# the point belongs to class1 and predicted1
# P(y=0|[-3.00443064 -7.0957359 ]) = 0.031719
# P(y=1|[-3.00443064 -7.0957359 ]) = 0.052735
# the point belongs to class1 and predicted1
# P(y=0|[-2.72033866 -6.04727555]) = 0.010985
# P(y=1|[-2.72033866 -6.04727555]) = 0.076398
# the point belongs to class1 and predicted1
# P(y=0|[-3.84248356 -6.03022442]) = 0.036769
# P(y=1|[-3.84248356 -6.03022442]) = 0.034962
# the point belongs to class1 and predicted0
# P(y=0|[-4.48354127 -8.58355591]) = 0.029515
# P(y=1|[-4.48354127 -8.58355591]) = 0.000954
# the point belongs to class0 and predicted0
# P(y=0|[-2.21182986 -7.42653926]) = 0.007543
# P(y=1|[-2.21182986 -7.42653926]) = 0.038519
# the point belongs to class1 and predicted1
# P(y=0|[-4.51775517 -6.41047648]) = 0.059868
# P(y=1|[-4.51775517 -6.41047648]) = 0.012101
# the point belongs to class1 and predicted0
# P(y=0|[-1.71866833 -9.08549259]) = 0.000375
# P(y=1|[-1.71866833 -9.08549259]) = 0.001097
# the point belongs to class1 and predicted1
# P(y=0|[-0.92380973 -5.43471743]) = 0.000045
# P(y=1|[-0.92380973 -5.43471743]) = 0.013150
# the point belongs to class1 and predicted1
# P(y=0|[-2.92651524 -7.10417036]) = 0.028429
# P(y=1|[-2.92651524 -7.10417036]) = 0.053914
# the point belongs to class1 and predicted1
# P(y=0|[-4.66970225 -5.5567578 ]) = 0.020932
# P(y=1|[-4.66970225 -5.5567578 ]) = 0.006871
# the point belongs to class1 and predicted0
# P(y=0|[-4.35783767 -6.85624562]) = 0.077015
# P(y=1|[-4.35783767 -6.85624562]) = 0.014009
# the point belongs to class0 and predicted0
# P(y=0|[-4.17650939 -6.66331662]) = 0.069888
# P(y=1|[-4.17650939 -6.66331662]) = 0.020860
# the point belongs to class0 and predicted0
# P(y=0|[-2.98251167 -6.92242407]) = 0.029921
# P(y=1|[-2.98251167 -6.92242407]) = 0.060223
# the point belongs to class0 and predicted1
# P(y=0|[-5.2014575  -6.87173424]) = 0.054291
# P(y=1|[-5.2014575  -6.87173424]) = 0.002134
# the point belongs to class0 and predicted0
# P(y=0|[-5.72644436 -4.53661232]) = 0.000979
# P(y=1|[-5.72644436 -4.53661232]) = 0.000119
# the point belongs to class0 and predicted0
# P(y=0|[-3.68762626 -6.9086854 ]) = 0.062059
# P(y=1|[-3.68762626 -6.9086854 ]) = 0.035856
# the point belongs to class0 and predicted0
# P(y=0|[-2.44799855 -5.89510244]) = 0.005606
# P(y=1|[-2.44799855 -5.89510244]) = 0.072483
# the point belongs to class1 and predicted1
# P(y=0|[-3.11431974 -6.92773192]) = 0.035697
# P(y=1|[-3.11431974 -6.92773192]) = 0.056524
# the point belongs to class1 and predicted1
# P(y=0|[-1.98230252 -6.28999783]) = 0.003125
# P(y=1|[-1.98230252 -6.28999783]) = 0.065126
# the point belongs to class1 and predicted1
# P(y=0|[-2.00914079 -6.3856404 ]) = 0.003609
# P(y=1|[-2.00914079 -6.3856404 ]) = 0.065900
# the point belongs to class1 and predicted1
# P(y=0|[-2.89133335 -5.07385647]) = 0.002989
# P(y=1|[-2.89133335 -5.07385647]) = 0.036540
# the point belongs to class1 and predicted1
# P(y=0|[-5.52638886 -7.59395378]) = 0.037362
# P(y=1|[-5.52638886 -7.59395378]) = 0.000434
# the point belongs to class1 and predicted0
# P(y=0|[-5.59134296 -7.61011631]) = 0.034303
# P(y=1|[-5.59134296 -7.61011631]) = 0.000350
# the point belongs to class0 and predicted0
# P(y=0|[-3.89359523 -6.148359  ]) = 0.042874
# P(y=1|[-3.89359523 -6.148359  ]) = 0.033500
# the point belongs to class1 and predicted0
# P(y=0|[-5.77126733 -6.98998342]) = 0.029267
# P(y=1|[-5.77126733 -6.98998342]) = 0.000371
# the point belongs to class0 and predicted0
# P(y=0|[-3.35301043 -5.42331034]) = 0.010459
# P(y=1|[-3.35301043 -5.42331034]) = 0.041001
# the point belongs to class1 and predicted1
# P(y=0|[-3.26369684 -6.42074288]) = 0.033126
# P(y=1|[-3.26369684 -6.42074288]) = 0.062779
# the point belongs to class1 and predicted1
# P(y=0|[-0.60794389 -8.34731821]) = 0.000032
# P(y=1|[-0.60794389 -8.34731821]) = 0.001274
# the point belongs to class1 and predicted1
# P(y=0|[-4.36493668 -8.08119671]) = 0.053379
# P(y=1|[-4.36493668 -8.08119671]) = 0.003294
# the point belongs to class0 and predicted0
# P(y=0|[-3.57211927 -7.66693828]) = 0.052092
# P(y=1|[-3.57211927 -7.66693828]) = 0.019075
# the point belongs to class1 and predicted0
# P(y=0|[-4.1691838  -5.81459629]) = 0.031599
# P(y=1|[-4.1691838  -5.81459629]) = 0.020259
# the point belongs to class0 and predicted0
# P(y=0|[-2.46639148 -5.50303679]) = 0.003258
# P(y=1|[-2.46639148 -5.50303679]) = 0.057811
# the point belongs to class1 and predicted1
# P(y=0|[-2.47833153 -7.14755864]) = 0.013422
# P(y=1|[-2.47833153 -7.14755864]) = 0.054454
# the point belongs to class1 and predicted1
# P(y=0|[-4.4093072  -4.83381309]) = 0.005239
# P(y=1|[-4.4093072  -4.83381309]) = 0.005251
# the point belongs to class1 and predicted1
# P(y=0|[-1.87484393 -5.51398283]) = 0.000894
# P(y=1|[-1.87484393 -5.51398283]) = 0.044960
# the point belongs to class1 and predicted1
# P(y=0|[-2.11893828 -6.72805927]) = 0.005750
# P(y=1|[-2.11893828 -6.72805927]) = 0.063872
# the point belongs to class1 and predicted1
# P(y=0|[-4.2311432  -7.60120781]) = 0.073069
# P(y=1|[-4.2311432  -7.60120781]) = 0.008697
# the point belongs to class0 and predicted0
# P(y=0|[-2.75948952 -5.94175192]) = 0.010344
# P(y=1|[-2.75948952 -5.94175192]) = 0.073682
# the point belongs to class1 and predicted1
# P(y=0|[-2.18567969 -6.34065896]) = 0.005214
# P(y=1|[-2.18567969 -6.34065896]) = 0.072402
# the point belongs to class1 and predicted1
# P(y=0|[-3.10358835 -9.06946885]) = 0.005946
# P(y=1|[-3.10358835 -9.06946885]) = 0.001501
# the point belongs to class0 and predicted0
# P(y=0|[-2.08002384 -6.66754123]) = 0.005111
# P(y=1|[-2.08002384 -6.66754123]) = 0.064173
# the point belongs to class1 and predicted1
# P(y=0|[-5.06876165 -7.51098592]) = 0.059395
# P(y=1|[-5.06876165 -7.51098592]) = 0.001695
# the point belongs to class0 and predicted0
# P(y=0|[-3.49747526 -5.87593447]) = 0.023914
# P(y=1|[-3.49747526 -5.87593447]) = 0.048363
# the point belongs to class0 and predicted1
# P(y=0|[-2.13512494 -5.08559797]) = 0.000745
# P(y=1|[-2.13512494 -5.08559797]) = 0.034617
# the point belongs to class1 and predicted1
# P(y=0|[-2.16198756 -6.65034963]) = 0.006101
# P(y=1|[-2.16198756 -6.65034963]) = 0.067226
# the point belongs to class1 and predicted1
# P(y=0|[-3.83135775 -7.93616549]) = 0.052251
# P(y=1|[-3.83135775 -7.93616549]) = 0.009521
# the point belongs to class0 and predicted0
# P(y=0|[-3.48367848 -9.01982342]) = 0.009847
# P(y=1|[-3.48367848 -9.01982342]) = 0.001315
# the point belongs to class0 and predicted0
# P(y=0|[-1.76333572 -3.95608711]) = 0.000015
# P(y=1|[-1.76333572 -3.95608711]) = 0.003735
# the point belongs to class1 and predicted1
# P(y=0|[-4.14099237 -6.94952184]) = 0.077008
# P(y=1|[-4.14099237 -6.94952184]) = 0.019048
# the point belongs to class0 and predicted0
# P(y=0|[-3.35665441 -7.34110336]) = 0.047761
# P(y=1|[-3.35665441 -7.34110336]) = 0.034157
# the point belongs to class1 and predicted0
# P(y=0|[-3.98219548 -6.66135158]) = 0.066024
# P(y=1|[-3.98219548 -6.66135158]) = 0.027973
# the point belongs to class0 and predicted0
# P(y=0|[-4.77462954 -7.51527768]) = 0.070001
# P(y=1|[-4.77462954 -7.51527768]) = 0.003381
# the point belongs to class0 and predicted0
# P(y=0|[-4.27809879 -6.10674698]) = 0.045732
# P(y=1|[-4.27809879 -6.10674698]) = 0.018602
# the point belongs to class0 and predicted0
# P(y=0|[-1.95850136 -5.718479  ]) = 0.001513
# P(y=1|[-1.95850136 -5.718479  ]) = 0.054618
# the point belongs to class1 and predicted1
# P(y=0|[-4.93547576 -8.22389356]) = 0.039324
# P(y=1|[-4.93547576 -8.22389356]) = 0.000769
# the point belongs to class0 and predicted0
# P(y=0|[-1.98133499 -7.75212556]) = 0.003879
# P(y=1|[-1.98133499 -7.75212556]) = 0.022470
# the point belongs to class1 and predicted1
# P(y=0|[-2.0057511  -7.00597429]) = 0.004809
# P(y=1|[-2.0057511  -7.00597429]) = 0.051161
# the point belongs to class1 and predicted1
# P(y=0|[-3.84661265 -8.93741036]) = 0.014773
# P(y=1|[-3.84661265 -8.93741036]) = 0.001105
# the point belongs to class0 and predicted0
# P(y=0|[-3.73407344 -5.10949836]) = 0.007881
# P(y=1|[-3.73407344 -5.10949836]) = 0.020695
# the point belongs to class1 and predicted1
# P(y=0|[-1.91167005 -7.1722028 ]) = 0.003878
# P(y=1|[-1.91167005 -7.1722028 ]) = 0.042148
# the point belongs to class1 and predicted1
# P(y=0|[-6.44183542 -5.85942665]) = 0.003860
# P(y=1|[-6.44183542 -5.85942665]) = 0.000039
# the point belongs to class0 and predicted0
# P(y=0|[-4.45879882 -8.31960945]) = 0.041539
# P(y=1|[-4.45879882 -8.31960945]) = 0.001762
# the point belongs to class0 and predicted0
# P(y=0|[-5.44592856 -7.12091731]) = 0.044732
# P(y=1|[-5.44592856 -7.12091731]) = 0.000909
# the point belongs to class0 and predicted0
# P(y=0|[-5.48727188 -6.38760511]) = 0.031464
# P(y=1|[-5.48727188 -6.38760511]) = 0.001131
# the point belongs to class0 and predicted0
# P(y=0|[-3.91407132 -8.17094993]) = 0.044220
# P(y=1|[-3.91407132 -8.17094993]) = 0.005670
# the point belongs to class0 and predicted0
# P(y=0|[-2.13162444 -7.43954609]) = 0.006293
# P(y=1|[-2.13162444 -7.43954609]) = 0.036643
# the point belongs to class1 and predicted1
# P(y=0|[-1.46663972 -7.00999789]) = 0.001150
# P(y=1|[-1.46663972 -7.00999789]) = 0.031708
# the point belongs to class1 and predicted1
# P(y=0|[-4.57445794 -7.95373119]) = 0.058166
# P(y=1|[-4.57445794 -7.95373119]) = 0.002751
# the point belongs to class0 and predicted0
# P(y=0|[-3.31733112 -7.99151855]) = 0.033179
# P(y=1|[-3.31733112 -7.99151855]) = 0.014456
# the point belongs to class0 and predicted0
# P(y=0|[-3.05147827 -5.04506777]) = 0.003523
# P(y=1|[-3.05147827 -5.04506777]) = 0.033214
# the point belongs to class1 and predicted1
# P(y=0|[-3.97228758 -7.82224731]) = 0.060511
# P(y=1|[-3.97228758 -7.82224731]) = 0.009455
# the point belongs to class0 and predicted0
# P(y=0|[-0.96781256 -6.20454534]) = 0.000149
# P(y=1|[-0.96781256 -6.20454534]) = 0.020248
# the point belongs to class1 and predicted1
# P(y=0|[-2.46403877 -7.50584151]) = 0.012346
# ...
# P(y=0|[-1.94856232 -7.4476509 ]) = 0.004085
# P(y=1|[-1.94856232 -7.4476509 ]) = 0.032693
# the point belongs to class1 and predicted1
# P(y=0|[-1.59593469 -5.79142869]) = 0.000650
# P(y=1|[-1.59593469 -5.79142869]) = 0.041857
# the point belongs to class1 and predicted1
# P(y=0|[-4.63682354 -6.81499293]) = 0.073152
# P(y=1|[-4.63682354 -6.81499293]) = 0.008357
# the point belongs to class0 and predicted0
# P(y=0|[-5.28344183 -5.64559382]) = 0.016462
# P(y=1|[-5.28344183 -5.64559382]) = 0.001652
# the point belongs to class0 and predicted0
# P(y=0|[-4.50282042 -6.72450846]) = 0.072537
# P(y=1|[-4.50282042 -6.72450846]) = 0.011418
# the point belongs to class0 and predicted0
# P(y=0|[-1.68860579 -6.23116414]) = 0.001398
# P(y=1|[-1.68860579 -6.23116414]) = 0.051697
# the point belongs to class1 and predicted1
# P(y=0|[-4.84794927 -7.03106777]) = 0.071190
# P(y=1|[-4.84794927 -7.03106777]) = 0.004601
# the point belongs to class0 and predicted0
# P(y=0|[-3.2102321  -6.19888297]) = 0.025741
# P(y=1|[-3.2102321  -6.19888297]) = 0.065309
# the point belongs to class1 and predicted1
# P(y=0|[-5.78515446 -8.1328465 ]) = 0.018327
# P(y=1|[-5.78515446 -8.1328465 ]) = 0.000084
# the point belongs to class0 and predicted0
# P(y=0|[-3.05769108 -6.70684914]) = 0.030686
# P(y=1|[-3.05769108 -6.70684914]) = 0.065278
# the point belongs to class0 and predicted1
# P(y=0|[-4.24086466 -7.55834238]) = 0.074460
# P(y=1|[-4.24086466 -7.55834238]) = 0.009041
# the point belongs to class0 and predicted0
# P(y=0|[-3.34574782 -5.1141887 ]) = 0.005759
# P(y=1|[-3.34574782 -5.1141887 ]) = 0.030167
# the point belongs to class1 and predicted1
# P(y=0|[-2.76540068 -6.13874748]) = 0.013055
# P(y=1|[-2.76540068 -6.13874748]) = 0.077256
# the point belongs to class1 and predicted1
# P(y=0|[-2.56906186 -7.59339113]) = 0.014528
# P(y=1|[-2.56906186 -7.59339113]) = 0.033980
# the point belongs to class0 and predicted1
# P(y=0|[-2.10177175 -7.18343769]) = 0.006098
# P(y=1|[-2.10177175 -7.18343769]) = 0.046831
# the point belongs to class1 and predicted1
# P(y=0|[-5.21702194 -6.23771259]) = 0.036228
# P(y=1|[-5.21702194 -6.23771259]) = 0.002422
# the point belongs to class0 and predicted0
# P(y=0|[-5.39519671 -7.25245925]) = 0.047120
# P(y=1|[-5.39519671 -7.25245925]) = 0.000935
# the point belongs to class0 and predicted0
# P(y=0|[-4.54094155 -6.42943391]) = 0.060493
# P(y=1|[-4.54094155 -6.42943391]) = 0.011533
# the point belongs to class0 and predicted0
# P(y=0|[-2.26125789 -7.31389185]) = 0.008580
# P(y=1|[-2.26125789 -7.31389185]) = 0.044278
# the point belongs to class1 and predicted1
# P(y=0|[-4.53846595 -6.53196758]) = 0.064965
# P(y=1|[-4.53846595 -6.53196758]) = 0.011364
# the point belongs to class0 and predicted0
# P(y=0|[-3.15798654 -7.78843191]) = 0.032044
# P(y=1|[-3.15798654 -7.78843191]) = 0.022134
# the point belongs to class1 and predicted0
# P(y=0|[-5.1920528  -7.37715023]) = 0.056006
# P(y=1|[-5.1920528  -7.37715023]) = 0.001438
# the point belongs to class0 and predicted0
# P(y=0|[-1.98286468 -5.92565072]) = 0.002123
# P(y=1|[-1.98286468 -5.92565072]) = 0.061050
# the point belongs to class1 and predicted1
# P(y=0|[-3.15528137 -8.2462994 ]) = 0.021649
# P(y=1|[-3.15528137 -8.2462994 ]) = 0.010106
# the point belongs to class0 and predicted0
# P(y=0|[-2.61260277 -7.06171563]) = 0.017081
# P(y=1|[-2.61260277 -7.06171563]) = 0.058827
# the point belongs to class1 and predicted1
# P(y=0|[-5.17394338 -8.05949036]) = 0.039076
# P(y=1|[-5.17394338 -8.05949036]) = 0.000573
# the point belongs to class0 and predicted0
# P(y=0|[-2.42518383 -5.00803656]) = 0.001163
# P(y=1|[-2.42518383 -5.00803656]) = 0.034603
# the point belongs to class1 and predicted1
# P(y=0|[-2.07699135 -8.36755052]) = 0.002808
# P(y=1|[-2.07699135 -8.36755052]) = 0.008055
# the point belongs to class1 and predicted1
# P(y=0|[-3.44916288 -6.82286828]) = 0.049909
# P(y=1|[-3.44916288 -6.82286828]) = 0.047640
# the point belongs to class1 and predicted0
# P(y=0|[-3.94651947 -6.7070545 ]) = 0.066545
# P(y=1|[-3.94651947 -6.7070545 ]) = 0.028870
# the point belongs to class1 and predicted0
# P(y=0|[-4.6023087  -7.93702972]) = 0.058554
# P(y=1|[-4.6023087  -7.93702972]) = 0.002672
# the point belongs to class0 and predicted0
# P(y=0|[-1.82907325 -6.06814577]) = 0.001713
# P(y=1|[-1.82907325 -6.06814577]) = 0.057040
# the point belongs to class1 and predicted1
# P(y=0|[-2.3068386  -5.55759533]) = 0.002591
# P(y=1|[-2.3068386  -5.55759533]) = 0.058160
# the point belongs to class1 and predicted1
# P(y=0|[-2.26414842 -7.94841905]) = 0.006439
# P(y=1|[-2.26414842 -7.94841905]) = 0.019030
# the point belongs to class1 and predicted1
# P(y=0|[-7.47357838 -5.24210343]) = 0.000095
# P(y=1|[-7.47357838 -5.24210343]) = 0.000000
# the point belongs to class0 and predicted0
# P(y=0|[-2.86897921 -4.95206534]) = 0.002221
# P(y=1|[-2.86897921 -4.95206534]) = 0.031525
# the point belongs to class1 and predicted1
# P(y=0|[-5.33625113 -7.52592807]) = 0.047102
# P(y=1|[-5.33625113 -7.52592807]) = 0.000819
# the point belongs to class0 and predicted0
# P(y=0|[-4.17322225 -7.91084705]) = 0.060346
# P(y=1|[-4.17322225 -7.91084705]) = 0.006089
# the point belongs to class0 and predicted0
# P(y=0|[-6.0772817  -6.32806157]) = 0.012868
# P(y=1|[-6.0772817  -6.32806157]) = 0.000168
# the point belongs to class0 and predicted0
# P(y=0|[-3.80809837 -9.05152225]) = 0.011742
# P(y=1|[-3.80809837 -9.05152225]) = 0.000854
# the point belongs to class0 and predicted0
# P(y=0|[-5.56992571 -7.64914507]) = 0.034591
# P(y=1|[-5.56992571 -7.64914507]) = 0.000354
# the point belongs to class0 and predicted0
# P(y=0|[-4.90506869 -8.8816304 ]) = 0.016075
# P(y=1|[-4.90506869 -8.8816304 ]) = 0.000188
# the point belongs to class0 and predicted0
# P(y=0|[-4.9720246  -8.87782272]) = 0.015563
# P(y=1|[-4.9720246  -8.87782272]) = 0.000162
# the point belongs to class0 and predicted0
# P(y=0|[-4.73475153 -7.93175308]) = 0.056443
# P(y=1|[-4.73475153 -7.93175308]) = 0.002039
# the point belongs to class0 and predicted0
# P(y=0|[-3.64127167 -7.84446661]) = 0.049487
# P(y=1|[-3.64127167 -7.84446661]) = 0.013723
# the point belongs to class1 and predicted0
# P(y=0|[-5.32552852 -6.63750565]) = 0.043991
# P(y=1|[-5.32552852 -6.63750565]) = 0.001699
# the point belongs to class0 and predicted0
# P(y=0|[-4.87472962 -5.93541573]) = 0.033027
# P(y=1|[-4.87472962 -5.93541573]) = 0.005350
# the point belongs to class0 and predicted0
# P(y=0|[-0.39529887 -5.81014971]) = 0.000011
# P(y=1|[-0.39529887 -5.81014971]) = 0.005918
# the point belongs to class1 and predicted1
# P(y=0|[-1.58032887 -4.52102365]) = 0.000048
# P(y=1|[-1.58032887 -4.52102365]) = 0.009900
# the point belongs to class1 and predicted1
# P(y=0|[-1.44659656 -8.40164651]) = 0.000513
# P(y=1|[-1.44659656 -8.40164651]) = 0.004374
# the point belongs to class1 and predicted1
# P(y=0|[-2.83079246 -7.55573757]) = 0.022907
# P(y=1|[-2.83079246 -7.55573757]) = 0.034730
# the point belongs to class1 and predicted1
# P(y=0|[-2.20766909 -5.23093811]) = 0.001173
# P(y=1|[-2.20766909 -5.23093811]) = 0.042054
# the point belongs to class1 and predicted1
# P(y=0|[-5.4299145  -4.83298165]) = 0.002948
# P(y=1|[-5.4299145  -4.83298165]) = 0.000470
# the point belongs to class0 and predicted0
# P(y=0|[-5.06403717 -7.34095639]) = 0.062250
# P(y=1|[-5.06403717 -7.34095639]) = 0.002078
# the point belongs to class0 and predicted0
# P(y=0|[-3.36499811 -6.04897725]) = 0.026027
# P(y=1|[-3.36499811 -6.04897725]) = 0.057201
# the point belongs to class0 and predicted1
# P(y=0|[-1.15181349 -6.59228036]) = 0.000373
# P(y=1|[-1.15181349 -6.59228036]) = 0.025909
# the point belongs to class1 and predicted1
# P(y=0|[-3.7692233  -7.60621982]) = 0.061526
# P(y=1|[-3.7692233  -7.60621982]) = 0.016691
# the point belongs to class0 and predicted0
# P(y=0|[-3.75105865 -5.04199434]) = 0.006912
# P(y=1|[-3.75105865 -5.04199434]) = 0.018709
# the point belongs to class0 and predicted1
# P(y=0|[-2.75027288 -6.93489953]) = 0.021119
# P(y=1|[-2.75027288 -6.93489953]) = 0.063611
# the point belongs to class1 and predicted1
# P(y=0|[-2.15935306 -8.02869185]) = 0.004800
# P(y=1|[-2.15935306 -8.02869185]) = 0.015942
# the point belongs to class1 and predicted1
# P(y=0|[-3.48231341 -5.86495715]) = 0.023261
# P(y=1|[-3.48231341 -5.86495715]) = 0.048810
# the point belongs to class1 and predicted1
# P(y=0|[-6.37333961 -7.30156807]) = 0.010431
# P(y=1|[-6.37333961 -7.30156807]) = 0.000034
# the point belongs to class0 and predicted0
# P(y=0|[-1.36965727 -6.4101105 ]) = 0.000653
# P(y=1|[-1.36965727 -6.4101105 ]) = 0.036267
# the point belongs to class1 and predicted1
# P(y=0|[-2.69374753 -5.49557795]) = 0.004847
# P(y=1|[-2.69374753 -5.49557795]) = 0.057763
# the point belongs to class1 and predicted1
# P(y=0|[-5.09197159 -7.59748286]) = 0.056492
# P(y=1|[-5.09197159 -7.59748286]) = 0.001434
# the point belongs to class0 and predicted0
# P(y=0|[-6.59664102 -6.75168572]) = 0.005972
# P(y=1|[-6.59664102 -6.75168572]) = 0.000021
# the point belongs to class0 and predicted0
# P(y=0|[-1.38405308 -5.7152815 ]) = 0.000315
# P(y=1|[-1.38405308 -5.7152815 ]) = 0.031622
# the point belongs to class1 and predicted1
# P(y=0|[-1.49545272 -4.94893882]) = 0.000107
# P(y=1|[-1.49545272 -4.94893882]) = 0.017453
# the point belongs to class1 and predicted1
# P(y=0|[-1.55853339 -6.61028654]) = 0.001297
# P(y=1|[-1.55853339 -6.61028654]) = 0.043194
# the point belongs to class1 and predicted1
# P(y=0|[-4.64051513 -7.26718367]) = 0.077483
# P(y=1|[-4.64051513 -7.26718367]) = 0.005915
# the point belongs to class0 and predicted0
# P(y=0|[-3.52656979 -8.12867104]) = 0.035827
# P(y=1|[-3.52656979 -8.12867104]) = 0.009536
# the point belongs to class0 and predicted0
# P(y=0|[-4.79193975 -6.29874893]) = 0.050410
# P(y=1|[-4.79193975 -6.29874893]) = 0.006868
# the point belongs to class0 and predicted0
# P(y=0|[-3.0757747  -6.59420838]) = 0.029631
# P(y=1|[-3.0757747  -6.59420838]) = 0.067398
# the point belongs to class1 and predicted1
# P(y=0|[-2.99429189 -6.4454448 ]) = 0.024105
# P(y=1|[-2.99429189 -6.4454448 ]) = 0.072303
# the point belongs to class1 and predicted1
# P(y=0|[-4.7591813  -6.77622777]) = 0.069178
# P(y=1|[-4.7591813  -6.77622777]) = 0.006561
# the point belongs to class0 and predicted0
# P(y=0|[-3.30480462 -7.31152098]) = 0.045454
# P(y=1|[-3.30480462 -7.31152098]) = 0.036597
# the point belongs to class0 and predicted0
# P(y=0|[-3.35825231 -4.21184696]) = 0.000604
# P(y=1|[-3.35825231 -4.21184696]) = 0.006981
# the point belongs to class1 and predicted1
# P(y=0|[-3.4030961  -7.45538735]) = 0.048728
# P(y=1|[-3.4030961  -7.45538735]) = 0.029027
# the point belongs to class1 and predicted0
# P(y=0|[-4.67446345 -7.33461082]) = 0.076032
# P(y=1|[-4.67446345 -7.33461082]) = 0.005148
# the point belongs to class0 and predicted0
# P(y=0|[-5.14452139 -7.61400923]) = 0.053884
# P(y=1|[-5.14452139 -7.61400923]) = 0.001226
# the point belongs to class0 and predicted0
# P(y=0|[-4.08544386 -7.85991138]) = 0.061301
# P(y=1|[-4.08544386 -7.85991138]) = 0.007568
# the point belongs to class0 and predicted0
# P(y=0|[-1.42263525 -7.64245652]) = 0.000915
# P(y=1|[-1.42263525 -7.64245652]) = 0.015693
# the point belongs to class1 and predicted1
# P(y=0|[-1.06152331 -6.66093123]) = 0.000288
# P(y=1|[-1.06152331 -6.66093123]) = 0.022064
# the point belongs to class1 and predicted1
# P(y=0|[-3.4948805  -7.32097361]) = 0.054625
# P(y=1|[-3.4948805  -7.32097361]) = 0.031052
# the point belongs to class0 and predicted0
# P(y=0|[-3.49674556 -7.55396635]) = 0.051403
# P(y=1|[-3.49674556 -7.55396635]) = 0.023767
# the point belongs to class0 and predicted0
# P(y=0|[-2.63296285 -6.79721966]) = 0.016609
# P(y=1|[-2.63296285 -6.79721966]) = 0.069584
# the point belongs to class1 and predicted1
# P(y=0|[-2.29339548 -6.89920817]) = 0.008941
# P(y=1|[-2.29339548 -6.89920817]) = 0.062672
# the point belongs to class1 and predicted1
# P(y=0|[-3.5184778 -7.5222897]) = 0.052994
# P(y=1|[-3.5184778 -7.5222897]) = 0.024228
# the point belongs to class0 and predicted0
# P(y=0|[-3.6572684  -5.29926337]) = 0.010876
# P(y=1|[-3.6572684  -5.29926337]) = 0.027645
# the point belongs to class1 and predicted1
# P(y=0|[-5.98502424 -8.05877301]) = 0.014438
# P(y=1|[-5.98502424 -8.05877301]) = 0.000049
# the point belongs to class0 and predicted0
# P(y=0|[-2.642675   -5.80035555]) = 0.007071
# P(y=1|[-2.642675   -5.80035555]) = 0.070328
# the point belongs to class1 and predicted1
# P(y=0|[-4.99536953 -7.63044222]) = 0.059489
# P(y=1|[-4.99536953 -7.63044222]) = 0.001746
# the point belongs to class0 and predicted0
# P(y=0|[-3.33319986 -6.26185024]) = 0.031284
# P(y=1|[-3.33319986 -6.26185024]) = 0.060263
# the point belongs to class1 and predicted1
# P(y=0|[-2.66612603 -7.76578038]) = 0.015789
# P(y=1|[-2.66612603 -7.76578038]) = 0.026741
# the point belongs to class1 and predicted1
# P(y=0|[-4.01692061 -6.72156545]) = 0.068835
# P(y=1|[-4.01692061 -6.72156545]) = 0.025988
# the point belongs to class0 and predicted0
# P(y=0|[-2.23941673 -7.79454652]) = 0.006805
# P(y=1|[-2.23941673 -7.79454652]) = 0.024020
# the point belongs to class1 and predicted1
# P(y=0|[-3.48433565 -6.46289184]) = 0.042597
# P(y=1|[-3.48433565 -6.46289184]) = 0.052430
# the point belongs to class0 and predicted1
# P(y=0|[-4.55336957 -6.56166165]) = 0.066000
# P(y=1|[-4.55336957 -6.56166165]) = 0.010950
# the point belongs to class0 and predicted0
# P(y=0|[-3.83614513 -4.43360436]) = 0.001647
# P(y=1|[-3.83614513 -4.43360436]) = 0.006622
# the point belongs to class1 and predicted1
# P(y=0|[-4.34935522 -8.3203919 ]) = 0.041687
# P(y=1|[-4.34935522 -8.3203919 ]) = 0.002151
# the point belongs to class0 and predicted0
# P(y=0|[-4.03486986 -5.30369282]) = 0.013362
# P(y=1|[-4.03486986 -5.30369282]) = 0.017199
# the point belongs to class0 and predicted1
# P(y=0|[-5.2167901  -6.43803463]) = 0.042828
# P(y=1|[-5.2167901  -6.43803463]) = 0.002400
# the point belongs to class0 and predicted0
# P(y=0|[-3.08573559 -6.80032491]) = 0.033097
# P(y=1|[-3.08573559 -6.80032491]) = 0.061684
# the point belongs to class1 and predicted1
# P(y=0|[-2.8255277  -7.26529352]) = 0.024367
# P(y=1|[-2.8255277  -7.26529352]) = 0.048052
# the point belongs to class1 and predicted1
# P(y=0|[-3.66167008 -6.23521318]) = 0.040694
# P(y=1|[-3.66167008 -6.23521318]) = 0.044602
# the point belongs to class1 and predicted1
# P(y=0|[-4.73952669 -6.5989112 ]) = 0.063978
# P(y=1|[-4.73952669 -6.5989112 ]) = 0.007349
# the point belongs to class0 and predicted0
# P(y=0|[-1.03816107 -5.53825001]) = 0.000080
# P(y=1|[-1.03816107 -5.53825001]) = 0.017246
# the point belongs to class1 and predicted1
# P(y=0|[-2.29298321 -5.40206423]) = 0.001934
# P(y=1|[-2.29298321 -5.40206423]) = 0.051128
# the point belongs to class1 and predicted1
# P(y=0|[-3.17415268 -7.34628644]) = 0.038968
# P(y=1|[-3.17415268 -7.34628644]) = 0.038436
# the point belongs to class1 and predicted0
# P(y=0|[-3.85046924 -8.0674253 ]) = 0.047310
# P(y=1|[-3.85046924 -8.0674253 ]) = 0.007435
# the point belongs to class1 and predicted0
# P(y=0|[-3.90317337 -5.32851311]) = 0.013276
# P(y=1|[-3.90317337 -5.32851311]) = 0.021164
# the point belongs to class1 and predicted1
# P(y=0|[-1.70432348 -5.66958979]) = 0.000734
# P(y=1|[-1.70432348 -5.66958979]) = 0.043469
# the point belongs to class1 and predicted1
# P(y=0|[-1.33045754 -6.58076959]) = 0.000651
# P(y=1|[-1.33045754 -6.58076959]) = 0.033306
# the point belongs to class1 and predicted1
# P(y=0|[-1.58912618 -5.76440131]) = 0.000614
# P(y=1|[-1.58912618 -5.76440131]) = 0.041001
# the point belongs to class1 and predicted1
# P(y=0|[-3.1272079  -7.77031346]) = 0.031193
# P(y=1|[-3.1272079  -7.77031346]) = 0.023125
# the point belongs to class0 and predicted0
# P(y=0|[-5.0415135  -7.75152876]) = 0.054166
# P(y=1|[-5.0415135  -7.75152876]) = 0.001317
# the point belongs to class0 and predicted0
# P(y=0|[-5.29539641 -8.72698583]) = 0.015490
# P(y=1|[-5.29539641 -8.72698583]) = 0.000103
# the point belongs to class0 and predicted0
# P(y=0|[-2.56248064 -5.72421922]) = 0.005506
# P(y=1|[-2.56248064 -5.72421922]) = 0.067598
# the point belongs to class1 and predicted1
# P(y=0|[-4.31959744 -5.97923109]) = 0.039703
# P(y=1|[-4.31959744 -5.97923109]) = 0.016786
# the point belongs to class0 and predicted0
# P(y=0|[-3.05500282 -5.30303853]) = 0.005932
# P(y=1|[-3.05500282 -5.30303853]) = 0.044092
# the point belongs to class1 and predicted1
# P(y=0|[-2.80254238 -6.31688069]) = 0.016391
# P(y=1|[-2.80254238 -6.31688069]) = 0.077540
# the point belongs to class0 and predicted1
# P(y=0|[-3.81469858 -5.7127853 ]) = 0.023958
# P(y=1|[-3.81469858 -5.7127853 ]) = 0.031753
# the point belongs to class1 and predicted1
